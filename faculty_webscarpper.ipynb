# %%
#Utilities import
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from tqdm import tqdm

# %%
#Defining the URLs for Scarping
lhr_URL = "https://lhr.nu.edu.pk/faculty/" 
pwr_URL = "https://pwr.nu.edu.pk/"
isb_URL = "https://isb.nu.edu.pk/Faculty/allfaculty/"
khi_URL = "https://khi.nu.edu.pk/faculty-php/"
cfd_URL = "https://cfd.nu.edu.pk/all-departments/"

# %%
#Save function
def save_csv(dataframe, name):
    # Clean and format data
    dataframe['HEC Approved PhD Supervisor'] = dataframe['HEC Approved PhD Supervisor'].astype(bool)
    dataframe = dataframe.drop_duplicates().reset_index(drop=True)
    dataframe.to_csv(name, index=False)

# %%
#Lahore Faculty
def extract_lhr_faculty_data(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    all_data = []

    # Find all department containers
    departments = soup.find_all('div', class_='container')

    for dept in tqdm(departments, desc="Processing Departments", unit="dept"):
        # Extract department name
        h1 = dept.find('h1', class_='mb-2 mt-3')
        if not h1:
            continue
        department_name = h1.get_text(strip=True).replace('Faculty', '').strip()

        # Extract faculty cards
        faculty_cards = dept.find_all('div', class_='facultyCard')

        for card in tqdm(faculty_cards, desc=f"Processing {department_name}", unit="faculty", leave=False):
            try:
                # Extract ID and faculty profile link
                faculty_link_tag = card.find('a', class_='faculty-link')
                if not faculty_link_tag:
                    continue
                faculty_link = "https://lhr.nu.edu.pk" + faculty_link_tag['href']
                faculty_id = int(faculty_link_tag['href'].split('/')[-1])

                # Extract Name
                name = card.find('h5', class_='text-center').get_text(strip=True)

                # Extract Designation and HEC Approval
                designation_tag = card.find('p', class_='small text-center font-italic')
                designation_lines = designation_tag.get_text('\n').split('\n') if designation_tag else []
                designation = designation_lines[0].strip() if designation_lines else ''
                hec_approved = any("HEC Approved PhD Supervisor" in line for line in designation_lines)

                # Extract Email
                email = card.find('p', class_='mb-0 text-center').get_text(strip=True)

                # Extract Image URL
                img = card.find('img')
                image_url = "https://lhr.nu.edu.pk" + img['src'] if img else None

                # Fetch Profile Page for Extension & Education
                profile_page = BeautifulSoup(requests.get(faculty_link).text, 'html.parser')

                # Extract Extension
                extension = None
                extension_tag = profile_page.find('span', class_='small')
                if extension_tag:
                    match = re.search(r'Ext[:\s]*([\d]+)', extension_tag.text.strip())
                    extension = match.group(1) if match else None

                # Extract Highest Education
                highest_education = None
                education_heading = profile_page.find('h2', string="Education")
                if education_heading:
                    education_list = education_heading.find_next('ul')
                    if education_list:
                        highest_education = education_list.find('li').get_text(strip=True)

                # Append extracted data
                all_data.append({
                    'ID': faculty_id,
                    'Name': name,
                    'Designation': designation,
                    'HEC Approved PhD Supervisor': hec_approved,
                    'Highest Education': highest_education,
                    'Email': email,
                    'Department': department_name,
                    'Extension': extension,
                    'ImageURL': image_url
                })

            except Exception as e:
                print(f"Error processing faculty in {department_name}: {e}")
                continue

    return all_data

# %%
response = requests.get(lhr_URL)
if response.status_code == 200:
    faculty_data = extract_lhr_faculty_data(response.text)
    df = pd.DataFrame(faculty_data)
    save_csv(df,'lhr.csv')
# Out:
# Processing Departments:   0%|          | 0/11 [00:00<?, ?dept/s]
# Processing FAST School of Computing:   0%|          | 0/98 [00:00<?, ?faculty/s]
# Processing FAST School of Computing:   1%|          | 1/98 [00:00<01:27,  1.10faculty/s]
# Processing FAST School of Computing:   2%|▏         | 2/98 [00:01<01:28,  1.08faculty/s]
# Processing FAST School of Computing:   3%|▎         | 3/98 [00:02<01:25,  1.12faculty/s]
# Processing FAST School of Computing:   4%|▍         | 4/98 [00:03<01:21,  1.15faculty/s]
# Processing FAST School of Computing:   5%|▌         | 5/98 [00:04<01:18,  1.18faculty/s]
# Processing FAST School of Computing:   6%|▌         | 6/98 [00:05<01:18,  1.17faculty/s]
# Processing FAST School of Computing:   7%|▋         | 7/98 [00:06<01:17,  1.18faculty/s]
# Processing FAST School of Computing:   8%|▊         | 8/98 [00:06<01:17,  1.15faculty/s]
# Processing FAST School of Computing:   9%|▉         | 9/98 [00:07<01:18,  1.13faculty/s]
# Processing FAST School of Computing:  10%|█         | 10/98 [00:08<01:18,  1.12faculty/s]
# Processing FAST School of Computing:  11%|█         | 11/98 [00:10<01:27,  1.01s/faculty]
# Processing FAST School of Computing:  12%|█▏        | 12/98 [00:10<01:23,  1.03faculty/s]
# Processing FAST School of Computing:  13%|█▎        | 13/98 [00:11<01:21,  1.04faculty/s]
# Processing FAST School of Computing:  14%|█▍        | 14/98 [00:12<01:19,  1.06faculty/s]
# Processing FAST School of Computing:  15%|█▌        | 15/98 [00:13<01:20,  1.03faculty/s]
# Processing FAST School of Computing:  16%|█▋        | 16/98 [00:14<01:18,  1.05faculty/s]
# Processing FAST School of Computing:  17%|█▋        | 17/98 [00:15<01:16,  1.06faculty/s]
# Processing FAST School of Computing:  18%|█▊        | 18/98 [00:16<01:15,  1.06faculty/s]
# Processing FAST School of Computing:  19%|█▉        | 19/98 [00:17<01:13,  1.07faculty/s]
# Processing FAST School of Computing:  20%|██        | 20/98 [00:18<01:12,  1.08faculty/s]
# Processing FAST School of Computing:  21%|██▏       | 21/98 [00:19<01:11,  1.08faculty/s]
# Processing FAST School of Computing:  22%|██▏       | 22/98 [00:20<01:10,  1.08faculty/s]
# Processing FAST School of Computing:  23%|██▎       | 23/98 [00:21<01:09,  1.08faculty/s]
# Processing FAST School of Computing:  24%|██▍       | 24/98 [00:22<01:08,  1.08faculty/s]
# Processing FAST School of Computing:  26%|██▌       | 25/98 [00:23<01:07,  1.08faculty/s]
# Processing FAST School of Computing:  27%|██▋       | 26/98 [00:23<01:04,  1.12faculty/s]
# Processing FAST School of Computing:  28%|██▊       | 27/98 [00:24<01:01,  1.15faculty/s]
# Processing FAST School of Computing:  29%|██▊       | 28/98 [00:25<01:01,  1.13faculty/s]
# Processing FAST School of Computing:  30%|██▉       | 29/98 [00:26<01:03,  1.08faculty/s]
# Processing FAST School of Computing:  31%|███       | 30/98 [00:27<01:02,  1.08faculty/s]
# Processing FAST School of Computing:  32%|███▏      | 31/98 [00:28<01:01,  1.10faculty/s]
# Processing FAST School of Computing:  33%|███▎      | 32/98 [00:29<00:59,  1.11faculty/s]
# Processing FAST School of Computing:  34%|███▎      | 33/98 [00:30<00:58,  1.11faculty/s]
# Processing FAST School of Computing:  35%|███▍      | 34/98 [00:31<00:58,  1.10faculty/s]
# Processing FAST School of Computing:  36%|███▌      | 35/98 [00:32<00:57,  1.09faculty/s]
# Processing FAST School of Computing:  37%|███▋      | 36/98 [00:32<00:56,  1.09faculty/s]
# Processing FAST School of Computing:  38%|███▊      | 37/98 [00:33<00:56,  1.08faculty/s]
# Processing FAST School of Computing:  39%|███▉      | 38/98 [00:34<00:54,  1.09faculty/s]
# Processing FAST School of Computing:  40%|███▉      | 39/98 [00:35<00:54,  1.09faculty/s]
# Processing FAST School of Computing:  41%|████      | 40/98 [00:36<00:53,  1.09faculty/s]
# Processing FAST School of Computing:  42%|████▏     | 41/98 [00:37<00:52,  1.09faculty/s]
# Processing FAST School of Computing:  43%|████▎     | 42/98 [00:38<00:51,  1.09faculty/s]
# Processing FAST School of Computing:  44%|████▍     | 43/98 [00:39<00:50,  1.10faculty/s]
# Processing FAST School of Computing:  45%|████▍     | 44/98 [00:40<00:49,  1.08faculty/s]
# Processing FAST School of Computing:  46%|████▌     | 45/98 [00:41<00:47,  1.11faculty/s]
# Processing FAST School of Computing:  47%|████▋     | 46/98 [00:42<00:47,  1.11faculty/s]
# Processing FAST School of Computing:  48%|████▊     | 47/98 [00:42<00:46,  1.11faculty/s]
# Processing FAST School of Computing:  49%|████▉     | 48/98 [00:43<00:44,  1.11faculty/s]
# Processing FAST School of Computing:  50%|█████     | 49/98 [00:44<00:43,  1.13faculty/s]
# Processing FAST School of Computing:  51%|█████     | 50/98 [00:45<00:41,  1.15faculty/s]
# Processing FAST School of Computing:  52%|█████▏    | 51/98 [00:46<00:41,  1.13faculty/s]
# Processing FAST School of Computing:  53%|█████▎    | 52/98 [00:47<00:40,  1.13faculty/s]
# Processing FAST School of Computing:  54%|█████▍    | 53/98 [00:48<00:39,  1.15faculty/s]
# Processing FAST School of Computing:  55%|█████▌    | 54/98 [00:49<00:38,  1.15faculty/s]
# Processing FAST School of Computing:  56%|█████▌    | 55/98 [00:49<00:37,  1.15faculty/s]
# Processing FAST School of Computing:  57%|█████▋    | 56/98 [00:50<00:36,  1.15faculty/s]
# Processing FAST School of Computing:  58%|█████▊    | 57/98 [00:51<00:35,  1.15faculty/s]
# Processing FAST School of Computing:  59%|█████▉    | 58/98 [00:52<00:34,  1.17faculty/s]
# Processing FAST School of Computing:  60%|██████    | 59/98 [00:53<00:33,  1.17faculty/s]
# Processing FAST School of Computing:  61%|██████    | 60/98 [00:54<00:32,  1.15faculty/s]
# Processing FAST School of Computing:  62%|██████▏   | 61/98 [00:55<00:32,  1.13faculty/s]
# Error processing faculty in FAST School of Computing: 'NoneType' object has no attribute 'get_text'
# Processing FAST School of Computing:  63%|██████▎   | 62/98 [00:56<00:31,  1.15faculty/s]
# Processing FAST School of Computing:  64%|██████▍   | 63/98 [00:56<00:30,  1.15faculty/s]
# Processing FAST School of Computing:  65%|██████▌   | 64/98 [00:57<00:29,  1.16faculty/s]
# Processing FAST School of Computing:  66%|██████▋   | 65/98 [00:58<00:29,  1.13faculty/s]
# Processing FAST School of Computing:  67%|██████▋   | 66/98 [00:59<00:29,  1.08faculty/s]
# Processing FAST School of Computing:  68%|██████▊   | 67/98 [01:00<00:28,  1.09faculty/s]
# Processing FAST School of Computing:  69%|██████▉   | 68/98 [01:01<00:27,  1.08faculty/s]
# Processing FAST School of Computing:  70%|███████   | 69/98 [01:02<00:26,  1.08faculty/s]
# Processing FAST School of Computing:  71%|███████▏  | 70/98 [01:03<00:25,  1.09faculty/s]
# Processing FAST School of Computing:  72%|███████▏  | 71/98 [01:04<00:24,  1.08faculty/s]
# Processing FAST School of Computing:  73%|███████▎  | 72/98 [01:05<00:23,  1.08faculty/s]
# Processing FAST School of Computing:  74%|███████▍  | 73/98 [01:06<00:23,  1.08faculty/s]
# Processing FAST School of Computing:  76%|███████▌  | 74/98 [01:07<00:22,  1.08faculty/s]
# Processing FAST School of Computing:  77%|███████▋  | 75/98 [01:08<00:24,  1.08s/faculty]
# Processing FAST School of Computing:  78%|███████▊  | 76/98 [01:09<00:22,  1.00s/faculty]
# Processing FAST School of Computing:  79%|███████▊  | 77/98 [01:10<00:20,  1.04faculty/s]
# Processing FAST School of Computing:  80%|███████▉  | 78/98 [01:11<00:19,  1.04faculty/s]
# Processing FAST School of Computing:  81%|████████  | 79/98 [01:12<00:18,  1.05faculty/s]
# Processing FAST School of Computing:  82%|████████▏ | 80/98 [01:13<00:17,  1.03faculty/s]
# Processing FAST School of Computing:  83%|████████▎ | 81/98 [01:14<00:16,  1.04faculty/s]
# Processing FAST School of Computing:  84%|████████▎ | 82/98 [01:14<00:15,  1.06faculty/s]
# Processing FAST School of Computing:  85%|████████▍ | 83/98 [01:15<00:14,  1.06faculty/s]
# Processing FAST School of Computing:  86%|████████▌ | 84/98 [01:16<00:12,  1.08faculty/s]
# Processing FAST School of Computing:  87%|████████▋ | 85/98 [01:17<00:12,  1.07faculty/s]
# Processing FAST School of Computing:  88%|████████▊ | 86/98 [01:18<00:11,  1.08faculty/s]
# Processing FAST School of Computing:  89%|████████▉ | 87/98 [01:19<00:10,  1.08faculty/s]
# Processing FAST School of Computing:  90%|████████▉ | 88/98 [01:20<00:09,  1.08faculty/s]
# Processing FAST School of Computing:  91%|█████████ | 89/98 [01:21<00:08,  1.08faculty/s]
# Processing FAST School of Computing:  92%|█████████▏| 90/98 [01:22<00:07,  1.08faculty/s]
# Processing FAST School of Computing:  93%|█████████▎| 91/98 [01:23<00:06,  1.09faculty/s]
# Processing FAST School of Computing:  94%|█████████▍| 92/98 [01:24<00:05,  1.08faculty/s]
# Processing FAST School of Computing:  95%|█████████▍| 93/98 [01:25<00:04,  1.08faculty/s]
# Processing FAST School of Computing:  96%|█████████▌| 94/98 [01:25<00:03,  1.09faculty/s]
# Processing FAST School of Computing:  97%|█████████▋| 95/98 [01:26<00:02,  1.08faculty/s]
# Processing FAST School of Computing:  98%|█████████▊| 96/98 [01:27<00:01,  1.08faculty/s]
# Processing FAST School of Computing:  99%|█████████▉| 97/98 [01:28<00:00,  1.08faculty/s]
# Processing FAST School of Computing: 100%|██████████| 98/98 [01:29<00:00,  1.11faculty/s]
# Processing Departments:  18%|█▊        | 2/11 [01:29<06:43, 44.81s/dept]
# Processing Department of Electrical Engineering:   0%|          | 0/30 [00:00<?, ?faculty/s]
# Processing Department of Electrical Engineering:   3%|▎         | 1/30 [00:00<00:23,  1.22faculty/s]
# Processing Department of Electrical Engineering:   7%|▋         | 2/30 [00:01<00:23,  1.18faculty/s]
# Processing Department of Electrical Engineering:  10%|█         | 3/30 [00:02<00:23,  1.13faculty/s]
# Processing Department of Electrical Engineering:  13%|█▎        | 4/30 [00:03<00:23,  1.11faculty/s]
# Processing Department of Electrical Engineering:  17%|█▋        | 5/30 [00:04<00:22,  1.10faculty/s]
# Processing Department of Electrical Engineering:  20%|██        | 6/30 [00:05<00:21,  1.09faculty/s]
# Processing Department of Electrical Engineering:  23%|██▎       | 7/30 [00:06<00:20,  1.10faculty/s]
# Processing Department of Electrical Engineering:  27%|██▋       | 8/30 [00:07<00:19,  1.14faculty/s]
# Processing Department of Electrical Engineering:  30%|███       | 9/30 [00:08<00:18,  1.11faculty/s]
# Processing Department of Electrical Engineering:  33%|███▎      | 10/30 [00:09<00:18,  1.07faculty/s]
# Processing Department of Electrical Engineering:  37%|███▋      | 11/30 [00:09<00:17,  1.07faculty/s]
# Processing Department of Electrical Engineering:  40%|████      | 12/30 [00:10<00:16,  1.07faculty/s]
# Processing Department of Electrical Engineering:  43%|████▎     | 13/30 [00:11<00:15,  1.08faculty/s]
# Processing Department of Electrical Engineering:  47%|████▋     | 14/30 [00:12<00:14,  1.09faculty/s]
# Processing Department of Electrical Engineering:  50%|█████     | 15/30 [00:13<00:13,  1.09faculty/s]
# Processing Department of Electrical Engineering:  53%|█████▎    | 16/30 [00:14<00:13,  1.03faculty/s]
# Processing Department of Electrical Engineering:  57%|█████▋    | 17/30 [00:15<00:12,  1.03faculty/s]
# Processing Department of Electrical Engineering:  60%|██████    | 18/30 [00:16<00:11,  1.05faculty/s]
# Processing Department of Electrical Engineering:  63%|██████▎   | 19/30 [00:17<00:10,  1.05faculty/s]
# Processing Department of Electrical Engineering:  67%|██████▋   | 20/30 [00:19<00:11,  1.12s/faculty]
# Processing Department of Electrical Engineering:  70%|███████   | 21/30 [00:19<00:09,  1.05s/faculty]
# Processing Department of Electrical Engineering:  73%|███████▎  | 22/30 [00:20<00:07,  1.03faculty/s]
# Processing Department of Electrical Engineering:  77%|███████▋  | 23/30 [00:21<00:06,  1.09faculty/s]
# Processing Department of Electrical Engineering:  80%|████████  | 24/30 [00:22<00:05,  1.12faculty/s]
# Processing Department of Electrical Engineering:  83%|████████▎ | 25/30 [00:23<00:04,  1.14faculty/s]
# Processing Department of Electrical Engineering:  87%|████████▋ | 26/30 [00:24<00:03,  1.10faculty/s]
# Processing Department of Electrical Engineering:  90%|█████████ | 27/30 [00:25<00:02,  1.09faculty/s]
# Processing Department of Electrical Engineering:  93%|█████████▎| 28/30 [00:26<00:01,  1.09faculty/s]
# Processing Department of Electrical Engineering:  97%|█████████▋| 29/30 [00:26<00:00,  1.09faculty/s]
# Processing Department of Electrical Engineering: 100%|██████████| 30/30 [00:27<00:00,  1.11faculty/s]
# Processing Departments:  36%|███▋      | 4/11 [01:57<03:06, 26.65s/dept]
# Processing Department of Civil Engineering:   0%|          | 0/21 [00:00<?, ?faculty/s]
# Processing Department of Civil Engineering:   5%|▍         | 1/21 [00:00<00:17,  1.15faculty/s]
# Processing Department of Civil Engineering:  10%|▉         | 2/21 [00:01<00:17,  1.12faculty/s]
# Processing Department of Civil Engineering:  14%|█▍        | 3/21 [00:03<00:20,  1.14s/faculty]
# Processing Department of Civil Engineering:  19%|█▉        | 4/21 [00:04<00:17,  1.05s/faculty]
# Processing Department of Civil Engineering:  24%|██▍       | 5/21 [00:05<00:16,  1.01s/faculty]
# Processing Department of Civil Engineering:  29%|██▊       | 6/21 [00:05<00:14,  1.03faculty/s]
# Processing Department of Civil Engineering:  33%|███▎      | 7/21 [00:06<00:12,  1.09faculty/s]
# Processing Department of Civil Engineering:  38%|███▊      | 8/21 [00:07<00:12,  1.08faculty/s]
# Processing Department of Civil Engineering:  43%|████▎     | 9/21 [00:08<00:11,  1.08faculty/s]
# Processing Department of Civil Engineering:  48%|████▊     | 10/21 [00:09<00:10,  1.08faculty/s]
# Processing Department of Civil Engineering:  52%|█████▏    | 11/21 [00:10<00:09,  1.08faculty/s]
# Processing Department of Civil Engineering:  57%|█████▋    | 12/21 [00:11<00:08,  1.08faculty/s]
# Processing Department of Civil Engineering:  62%|██████▏   | 13/21 [00:12<00:07,  1.12faculty/s]
# Processing Department of Civil Engineering:  67%|██████▋   | 14/21 [00:13<00:06,  1.11faculty/s]
# Processing Department of Civil Engineering:  71%|███████▏  | 15/21 [00:14<00:05,  1.11faculty/s]
# Processing Department of Civil Engineering:  76%|███████▌  | 16/21 [00:14<00:04,  1.10faculty/s]
# Processing Department of Civil Engineering:  81%|████████  | 17/21 [00:15<00:03,  1.09faculty/s]
# Processing Department of Civil Engineering:  86%|████████▌ | 18/21 [00:16<00:02,  1.09faculty/s]
# Processing Department of Civil Engineering:  90%|█████████ | 19/21 [00:17<00:01,  1.09faculty/s]
# Processing Department of Civil Engineering:  95%|█████████▌| 20/21 [00:18<00:00,  1.09faculty/s]
# Processing Department of Civil Engineering: 100%|██████████| 21/21 [00:19<00:00,  1.09faculty/s]
# Processing Departments:  55%|█████▍    | 6/11 [02:17<01:34, 18.96s/dept]
# Processing FAST School of Management:   0%|          | 0/37 [00:00<?, ?faculty/s]
# Processing FAST School of Management:   3%|▎         | 1/37 [00:00<00:33,  1.08faculty/s]
# Processing FAST School of Management:   5%|▌         | 2/37 [00:01<00:32,  1.08faculty/s]
# Processing FAST School of Management:   8%|▊         | 3/37 [00:02<00:32,  1.03faculty/s]
# Processing FAST School of Management:  11%|█         | 4/37 [00:03<00:32,  1.01faculty/s]
# Processing FAST School of Management:  14%|█▎        | 5/37 [00:04<00:29,  1.08faculty/s]
# Processing FAST School of Management:  16%|█▌        | 6/37 [00:05<00:28,  1.08faculty/s]
# Processing FAST School of Management:  19%|█▉        | 7/37 [00:06<00:27,  1.08faculty/s]
# Processing FAST School of Management:  22%|██▏       | 8/37 [00:07<00:26,  1.08faculty/s]
# Processing FAST School of Management:  24%|██▍       | 9/37 [00:08<00:25,  1.09faculty/s]
# Processing FAST School of Management:  27%|██▋       | 10/37 [00:09<00:24,  1.09faculty/s]
# Processing FAST School of Management:  30%|██▉       | 11/37 [00:10<00:23,  1.09faculty/s]
# Processing FAST School of Management:  32%|███▏      | 12/37 [00:11<00:27,  1.11s/faculty]
# Processing FAST School of Management:  35%|███▌      | 13/37 [00:12<00:25,  1.05s/faculty]
# Processing FAST School of Management:  38%|███▊      | 14/37 [00:13<00:23,  1.01s/faculty]
# Processing FAST School of Management:  41%|████      | 15/37 [00:14<00:21,  1.01faculty/s]
# Processing FAST School of Management:  43%|████▎     | 16/37 [00:15<00:20,  1.03faculty/s]
# Processing FAST School of Management:  46%|████▌     | 17/37 [00:16<00:18,  1.07faculty/s]
# Processing FAST School of Management:  49%|████▊     | 18/37 [00:17<00:18,  1.05faculty/s]
# Processing FAST School of Management:  51%|█████▏    | 19/37 [00:18<00:16,  1.06faculty/s]
# Processing FAST School of Management:  54%|█████▍    | 20/37 [00:19<00:19,  1.12s/faculty]
# Processing FAST School of Management:  57%|█████▋    | 21/37 [00:20<00:16,  1.06s/faculty]
# Processing FAST School of Management:  59%|█████▉    | 22/37 [00:21<00:14,  1.01faculty/s]
# Processing FAST School of Management:  62%|██████▏   | 23/37 [00:22<00:13,  1.06faculty/s]
# Processing FAST School of Management:  65%|██████▍   | 24/37 [00:23<00:11,  1.11faculty/s]
# Processing FAST School of Management:  68%|██████▊   | 25/37 [00:24<00:10,  1.10faculty/s]
# Processing FAST School of Management:  70%|███████   | 26/37 [00:24<00:10,  1.10faculty/s]
# Processing FAST School of Management:  73%|███████▎  | 27/37 [00:26<00:09,  1.06faculty/s]
# Processing FAST School of Management:  76%|███████▌  | 28/37 [00:26<00:08,  1.07faculty/s]
# Processing FAST School of Management:  78%|███████▊  | 29/37 [00:27<00:07,  1.07faculty/s]
# Processing FAST School of Management:  81%|████████  | 30/37 [00:28<00:06,  1.08faculty/s]
# Processing FAST School of Management:  84%|████████▍ | 31/37 [00:29<00:05,  1.09faculty/s]
# Processing FAST School of Management:  86%|████████▋ | 32/37 [00:30<00:04,  1.07faculty/s]
# Processing FAST School of Management:  89%|████████▉ | 33/37 [00:31<00:03,  1.08faculty/s]
# Processing FAST School of Management:  92%|█████████▏| 34/37 [00:32<00:02,  1.08faculty/s]
# Processing FAST School of Management:  95%|█████████▍| 35/37 [00:33<00:01,  1.08faculty/s]
# Processing FAST School of Management:  97%|█████████▋| 36/37 [00:34<00:00,  1.08faculty/s]
# Processing FAST School of Management: 100%|██████████| 37/37 [00:35<00:00,  1.11s/faculty]
# Processing Departments:  73%|███████▎  | 8/11 [02:52<00:55, 18.55s/dept]
# Processing Department of Science & Humanities:   0%|          | 0/32 [00:00<?, ?faculty/s]
# Processing Department of Science & Humanities:   3%|▎         | 1/32 [00:00<00:29,  1.05faculty/s]
# Processing Department of Science & Humanities:   6%|▋         | 2/32 [00:01<00:27,  1.11faculty/s]
# Processing Department of Science & Humanities:   9%|▉         | 3/32 [00:02<00:26,  1.09faculty/s]
# Processing Department of Science & Humanities:  12%|█▎        | 4/32 [00:03<00:25,  1.09faculty/s]
# Processing Department of Science & Humanities:  16%|█▌        | 5/32 [00:04<00:24,  1.10faculty/s]
# Processing Department of Science & Humanities:  19%|█▉        | 6/32 [00:05<00:23,  1.09faculty/s]
# Processing Department of Science & Humanities:  22%|██▏       | 7/32 [00:06<00:23,  1.05faculty/s]
# Processing Department of Science & Humanities:  25%|██▌       | 8/32 [00:07<00:22,  1.06faculty/s]
# Processing Department of Science & Humanities:  28%|██▊       | 9/32 [00:08<00:21,  1.06faculty/s]
# Processing Department of Science & Humanities:  31%|███▏      | 10/32 [00:09<00:20,  1.07faculty/s]
# Processing Department of Science & Humanities:  34%|███▍      | 11/32 [00:10<00:19,  1.08faculty/s]
# Processing Department of Science & Humanities:  38%|███▊      | 12/32 [00:11<00:18,  1.08faculty/s]
# Processing Department of Science & Humanities:  41%|████      | 13/32 [00:12<00:17,  1.08faculty/s]
# Processing Department of Science & Humanities:  44%|████▍     | 14/32 [00:12<00:16,  1.08faculty/s]
# Processing Department of Science & Humanities:  47%|████▋     | 15/32 [00:13<00:15,  1.11faculty/s]
# Processing Department of Science & Humanities:  50%|█████     | 16/32 [00:14<00:14,  1.11faculty/s]
# Processing Department of Science & Humanities:  53%|█████▎    | 17/32 [00:15<00:13,  1.10faculty/s]
# Processing Department of Science & Humanities:  56%|█████▋    | 18/32 [00:16<00:12,  1.10faculty/s]
# Processing Department of Science & Humanities:  59%|█████▉    | 19/32 [00:18<00:14,  1.10s/faculty]
# Processing Department of Science & Humanities:  62%|██████▎   | 20/32 [00:19<00:12,  1.04s/faculty]
# Processing Department of Science & Humanities:  66%|██████▌   | 21/32 [00:19<00:11,  1.01s/faculty]
# Processing Department of Science & Humanities:  69%|██████▉   | 22/32 [00:20<00:09,  1.02faculty/s]
# Processing Department of Science & Humanities:  72%|███████▏  | 23/32 [00:21<00:08,  1.04faculty/s]
# Processing Department of Science & Humanities:  75%|███████▌  | 24/32 [00:22<00:07,  1.05faculty/s]
# Processing Department of Science & Humanities:  78%|███████▊  | 25/32 [00:23<00:06,  1.06faculty/s]
# Processing Department of Science & Humanities:  81%|████████▏ | 26/32 [00:24<00:05,  1.07faculty/s]
# Processing Department of Science & Humanities:  84%|████████▍ | 27/32 [00:26<00:05,  1.12s/faculty]
# Processing Department of Science & Humanities:  88%|████████▊ | 28/32 [00:26<00:04,  1.03s/faculty]
# Processing Department of Science & Humanities:  91%|█████████ | 29/32 [00:27<00:02,  1.04faculty/s]
# Processing Department of Science & Humanities:  94%|█████████▍| 30/32 [00:28<00:01,  1.08faculty/s]
# Processing Department of Science & Humanities:  97%|█████████▋| 31/32 [00:29<00:00,  1.09faculty/s]
# Processing Department of Science & Humanities: 100%|██████████| 32/32 [00:30<00:00,  1.09faculty/s]
# Processing Departments: 100%|██████████| 11/11 [03:23<00:00, 18.49s/dept]

# %%
#Karachi Faculty
def extract_khi_faculty_data(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    all_data = []

    departments_tag = soup.find('li',
                                class_='menu-item menu-item-type-custom menu-item-object-custom current-menu-ancestor current-menu-parent menu-item-has-children menu-item-6256')
    departments = departments_tag.find_all('li', class_='menu-item')

    department_data = [(dept.a.text.strip(), dept.a['href']) for dept in departments]
    serial_number = 1

    for name, link in department_data:
        department_name = name
        response_inner = requests.get(link)
        faculty = BeautifulSoup(response_inner.text, 'html.parser')
        faculty_cards = faculty.find_all('div', class_="gdlr-core-personnel-list-column")
        print("Scraping: "+department_name)
        for card in faculty_cards:
            try:
                faculty_link = card.find('a')
                response_inner_inner = requests.get(faculty_link['href'])
                faculty_page = BeautifulSoup(response_inner_inner.text, 'html.parser')

                email_tag = faculty_page.find('div', class_='kingster-personnel-info-list kingster-type-email')
                extension_tag = faculty_page.find('div', class_='kingster-personnel-info-list kingster-type-phone')
                name_tag = faculty_page.find('h3', class_='gdlr-core-title-item-title gdlr-core-skin-title')
                designation_hec_tag = faculty_page.find('span',
                                                        class_='gdlr-core-title-item-caption gdlr-core-info-font gdlr-core-skin-caption')
                image_tag = faculty_page.find('a', class_='gdlr-core-lightgallery gdlr-core-js')

                email = email_tag.text.strip() if email_tag else 'N/A'
                extension = extension_tag.text.strip() if extension_tag else 'N/A'
                name = name_tag.text.strip() if name_tag else 'N/A'
                designation = 'N/A'
                hec_approved = False

                if designation_hec_tag:
                    designation_text = designation_hec_tag.get_text(separator=' ').strip()
                    designation = designation_text.split('\n')[0].strip()
                    hec_approved = 'HEC Approved PhD Supervisor' in designation_text

                image_url = image_tag['href'] if image_tag else 'N/A'

                education = 'N/A'
                education_heading = faculty_page.find('i', class_='gdlr-core-icon-list-icon fa fa-graduation-cap')

                if education_heading:
                    education_tag = education_heading.find_next('span')
                    if education_tag:
                        education = education_tag.text.strip()

                if education == 'N/A':
                    education_heading = faculty_page.find(lambda tag: tag.name in ['h3'] and "Education" in tag.text)
                    if education_heading:
                        education_tag = education_heading.find_next('span')
                        if education_tag:
                            education = education_tag.text.strip()

                all_data.append({
                    'ID': serial_number,
                    'Name': name,
                    'Designation': designation,
                    'HEC Approved PhD Supervisor': hec_approved,
                    'Highest Education': education,
                    'Email': email,
                    'Department': department_name,
                    'Extension': extension,
                    'ImageURL': image_url
                })
                serial_number += 1

            except Exception as e:
                print(f"Error processing faculty in {department_name}: {e}")
                continue

    return all_data

# %%
response = requests.get(khi_URL)
if response.status_code == 200:
    faculty_data = extract_khi_faculty_data(response.text)
    df = pd.DataFrame(faculty_data)
    save_csv(df,'khi.csv')
# Out:
# Scraping: Department of Computer Science
# Scraping: Department of Cyber Security
# Scraping: Department of Artificial Intelligence
# Scraping: Department of Software Engineering
# Scraping: Department of Electrical Engineering
# Scraping: Department of Management Sciences
# Scraping: Department of Sciences & Humanities

# %%
#Faisalabad Faculty
def extract_cfd_faculty_data(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    all_data = []
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }
    serial_number = 152
    departments_tag = soup.find('div', class_='kc-elm kc-css-633007 kc_row kc_row_inner')
    departments = departments_tag.find_all('div', class_='kc_col-sm-3')
    for dept in departments:
        department_name = dept.find('div', class_='content-desc').text.strip()
        department_link = dept.find('a')['href']
        response_inner = requests.get(department_link, headers=headers)
        faculty = BeautifulSoup(response_inner.text, 'html.parser')
        faculty_cards = faculty.find_all('div', class_="col-md-3 col-sm-6 col-xs-12")
        for card in faculty_cards:
            try:
                # Extract profile page link
                profile_link_tag = card.find('a', href=True)
                profile_link = profile_link_tag['href'] if profile_link_tag else 'N/A'
                response_inner_inner = requests.get(profile_link, headers=headers)
                profile = BeautifulSoup(response_inner_inner.text, 'html.parser')
                # Find the <li> containing the <span> with text "Ext:"
                teacher_address = profile.find('ul', class_='teacher__address')
                # Find the <li> where <span> contains "Ext:"
                ext_li = teacher_address.find_all('li')
                print(profile_link)

                # Extract the extension number by removing "Ext:" text
                extension = ext_li[3].get_text(strip=True).replace("Ext:", "").strip() if ext_li[3] else 'N/A'
                education = 'N/A'
                education_tag = profile.find('div', class_='htc__skill__container progress__bar--2')
                education = 'N/A'
                if education_tag.find('p'):
                    education = education_tag.find_all('p')[0].text
                if education_tag.find('li'):
                    education = education_tag.find_all('li')[0].text

                education = education.replace("\n", " ").strip()
                # Extract image URL
                image_tag = card.find('img')
                image_url = image_tag['src'] if image_tag else 'N/A'

                # Extract name
                name_tag = card.find('h4')
                name = name_tag.text.strip() if name_tag else 'N/A'

                # Extract designation
                designation_tag = card.find('h6')
                designation = designation_tag.text.strip() if designation_tag else 'N/A'

                # Check for HEC approval
                hec_approved = 'HEC approved PhD Supervisor' in card.text

                # Extract email
                email_tag = card.find('p')
                email = email_tag.text.strip() if email_tag else 'N/A'
                # Store extracted data
                all_data.append({
                    'ID': serial_number,
                    'Name': name,
                    'Designation': designation,
                    'HEC Approved PhD Supervisor': hec_approved,
                    'Highest Education': education,
                    'Email': email,
                    'Department': department_name,
                    'Extension': extension,
                    'ImageURL': image_url,
                })
                serial_number += 1

            except Exception as e:
                print(f"Error processing faculty card: {e}")
                continue

    return all_data

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}
response = requests.get(cfd_URL,headers=headers)
if response.status_code == 200:
    faculty_data = extract_cfd_faculty_data(response.text)
    df = pd.DataFrame(faculty_data)
    save_csv(df,'cfd.csv')
# Out:
# https://cfd.nu.edu.pk/faculty/muhammad-fayyaz/
# https://cfd.nu.edu.pk/faculty/muhammad-shahzad-sarfraz/
# https://cfd.nu.edu.pk/faculty/muhammad-umar-aftab/
# https://cfd.nu.edu.pk/faculty/muhammad-usama/
# https://cfd.nu.edu.pk/faculty/ammar-rafiq/
# https://cfd.nu.edu.pk/faculty/iqra-muhammad/
# https://cfd.nu.edu.pk/faculty/rabia-maqsood/
# https://cfd.nu.edu.pk/faculty/usman-ghous/
# https://cfd.nu.edu.pk/faculty/adeel-ashraf-cheema/
# https://cfd.nu.edu.pk/faculty/asma-sattar/
# https://cfd.nu.edu.pk/faculty/hafiz-tayyeb-javed/
# https://cfd.nu.edu.pk/faculty/maria-maqsood/
# https://cfd.nu.edu.pk/faculty/muhammad-atif/
# https://cfd.nu.edu.pk/faculty/rida-ghafoor-hussain/
# https://cfd.nu.edu.pk/faculty/rizwan-ul-haq/
# https://cfd.nu.edu.pk/faculty/zain-iqbal/
# https://cfd.nu.edu.pk/faculty/ahmad-ali-tabassam/
# https://cfd.nu.edu.pk/faculty/ali-hamza/
# https://cfd.nu.edu.pk/faculty/ali-raza/
# https://cfd.nu.edu.pk/faculty/aliza-saeed/
# https://cfd.nu.edu.pk/faculty/aqsa-younas/
# https://cfd.nu.edu.pk/faculty/ayesha-liaqat/
# https://cfd.nu.edu.pk/faculty/faryal-saud/
# https://cfd.nu.edu.pk/faculty/juhinah-batool-asif/
# https://cfd.nu.edu.pk/faculty/kashaf-shakoor/
# https://cfd.nu.edu.pk/faculty/mahzaib-younas/
# https://cfd.nu.edu.pk/faculty/masood-habib/
# https://cfd.nu.edu.pk/faculty/mazhar-hussain/
# https://cfd.nu.edu.pk/faculty/momna-javaid/
# https://cfd.nu.edu.pk/faculty/mughees-ismail/
# https://cfd.nu.edu.pk/faculty/muhammad-adeel/
# https://cfd.nu.edu.pk/faculty/muhammad-hannan-farooq/
# https://cfd.nu.edu.pk/faculty/haseeb-arshad/
# https://cfd.nu.edu.pk/faculty/muhammad-shahbaz-ayyaz/
# https://cfd.nu.edu.pk/faculty/muhammad-suffian/
# https://cfd.nu.edu.pk/faculty/muiz-qadir/
# https://cfd.nu.edu.pk/faculty/nasreen-akhtar/
# https://cfd.nu.edu.pk/faculty/saba-aslam/
# https://cfd.nu.edu.pk/faculty/507221/
# https://cfd.nu.edu.pk/faculty/sadia-ramzan/
# https://cfd.nu.edu.pk/faculty/samia-mujahid/
# https://cfd.nu.edu.pk/faculty/saqib-hayat/
# https://cfd.nu.edu.pk/faculty/sumaira-mustafa/
# https://cfd.nu.edu.pk/faculty/ms-wania-fatima/
# https://cfd.nu.edu.pk/faculty/amna-waheed/
# https://cfd.nu.edu.pk/faculty/areeba-waseem/
# https://cfd.nu.edu.pk/faculty/gul-e-zahra/
# https://cfd.nu.edu.pk/faculty/hassan-ahmed/
# https://cfd.nu.edu.pk/faculty/maham-saleem/
# https://cfd.nu.edu.pk/faculty/rabia-anwar/
# https://cfd.nu.edu.pk/faculty/rana-mobeen-tariq/
# https://cfd.nu.edu.pk/faculty/509252/
# https://cfd.nu.edu.pk/faculty/qamar-uz-zaman/
# https://cfd.nu.edu.pk/faculty/affan-rauf/
# https://cfd.nu.edu.pk/faculty/amer-rasheed/
# https://cfd.nu.edu.pk/faculty/shamsa-abid/
# https://cfd.nu.edu.pk/faculty/shanza-abbas/
# https://cfd.nu.edu.pk/faculty/anmol-bilal/
# https://cfd.nu.edu.pk/faculty/awais-azam/
# https://cfd.nu.edu.pk/faculty/fraz-zaheer-gorsi/
# https://cfd.nu.edu.pk/faculty/jawad-khalid-cheema/
# https://cfd.nu.edu.pk/faculty/kanwal-naz/
# https://cfd.nu.edu.pk/faculty/naba-rahim/
# https://cfd.nu.edu.pk/faculty/sahar-ajmal/
# https://cfd.nu.edu.pk/faculty/samia-aziz/
# https://cfd.nu.edu.pk/faculty/saqib-ameer/
# https://cfd.nu.edu.pk/faculty/tehreem-aslam/
# https://cfd.nu.edu.pk/faculty/umer-iqbal/
# https://cfd.nu.edu.pk/faculty/hashim-yasin/
# https://cfd.nu.edu.pk/faculty/anwar-shah/
# https://cfd.nu.edu.pk/faculty/asif-ameer/
# https://cfd.nu.edu.pk/faculty/hamza-yousaf/
# https://cfd.nu.edu.pk/faculty/muhammad-yousaf/
# https://cfd.nu.edu.pk/faculty/rukhsana-zafar/
# https://cfd.nu.edu.pk/faculty/tahir-farooq/
# https://cfd.nu.edu.pk/faculty/isma-waheed/
# https://cfd.nu.edu.pk/faculty/muhammad-shoaib-khalid/
# https://cfd.nu.edu.pk/faculty/arslan-ahmed-amin/
# https://cfd.nu.edu.pk/faculty/adil-zulfiqar/
# https://cfd.nu.edu.pk/faculty/muhammad-adnan/
# https://cfd.nu.edu.pk/faculty/shahzad/
# https://cfd.nu.edu.pk/faculty/amir-zahoor/
# https://cfd.nu.edu.pk/faculty/habib-ullah/
# https://cfd.nu.edu.pk/faculty/muhammad-irfan-ishaq/
# https://cfd.nu.edu.pk/faculty/ameer-hamza/
# https://cfd.nu.edu.pk/faculty/amna-saghir/
# https://cfd.nu.edu.pk/faculty/bakhtawar-saeed/
# https://cfd.nu.edu.pk/faculty/muhammad-abdullah/
# https://cfd.nu.edu.pk/faculty/muhammad-faisal-hayat/
# https://cfd.nu.edu.pk/faculty/sajid-iqbal/
# https://cfd.nu.edu.pk/faculty/ayesha-nadeem/
# https://cfd.nu.edu.pk/faculty/hafiz-muhammad-qasim/
# https://cfd.nu.edu.pk/faculty/dr-mushtaq-ahmed/
# https://cfd.nu.edu.pk/faculty/haris-khurram/
# https://cfd.nu.edu.pk/faculty/amjad-hussain/
# https://cfd.nu.edu.pk/faculty/arfan-shahzad/
# https://cfd.nu.edu.pk/faculty/m-nouman-iftikhar/
# https://cfd.nu.edu.pk/faculty/munaza-akhter/
# https://cfd.nu.edu.pk/faculty/anoosha-rehan/
# https://cfd.nu.edu.pk/faculty/ghilmana-sarmad/
# https://cfd.nu.edu.pk/faculty/ms-hadiqa-iqbal/
# https://cfd.nu.edu.pk/faculty/hassan-ali/
# https://cfd.nu.edu.pk/faculty/hayat-ali/
# https://cfd.nu.edu.pk/faculty/khalid-mehmood-anjum/
# https://cfd.nu.edu.pk/faculty/muhammad-iqbal/
# https://cfd.nu.edu.pk/faculty/muhammad-munawar/
# https://cfd.nu.edu.pk/faculty/muhammad-shoaib/
# https://cfd.nu.edu.pk/faculty/rida-akram/
# https://cfd.nu.edu.pk/faculty/rimsha-bashir-awan/
# https://cfd.nu.edu.pk/faculty/rizwan-ullah/
# https://cfd.nu.edu.pk/faculty/sadia-ashfaq/
# https://cfd.nu.edu.pk/faculty/ms-tehreem-wali/
# https://cfd.nu.edu.pk/faculty/zainab-mubarik/
# https://cfd.nu.edu.pk/faculty/zartash-naqvi/
# https://cfd.nu.edu.pk/faculty/abdul-rehman/
# https://cfd.nu.edu.pk/faculty/muhammad-hasnain/
# https://cfd.nu.edu.pk/faculty/muhammad-usama-ashfaq/
# https://cfd.nu.edu.pk/faculty/4852/
# https://cfd.nu.edu.pk/faculty/muhammad-rafiq/
# https://cfd.nu.edu.pk/faculty/misbah-hayat-bhatti/
# https://cfd.nu.edu.pk/faculty/saifullah/
# https://cfd.nu.edu.pk/faculty/mr-syed-zeeshan-haider/
# https://cfd.nu.edu.pk/faculty/ahmad-salah-ud-din/
# https://cfd.nu.edu.pk/faculty/amna-babar-tirmizey/
# https://cfd.nu.edu.pk/faculty/mr-hafiz-muhammad-zeeshan-raza/
# https://cfd.nu.edu.pk/faculty/mr-muhammad-nasif/

# %%
#Islamabad Faculty
from datetime import datetime

# Base URLs
faculty_api_url = "http://isb.nu.edu.pk/Faculty/GetAllEmp?id={}"
faculty_profile_url = "http://isb.nu.edu.pk/Faculty/Details1?id={}"  

# Department ID to Name Mapping
department_mapping = {
    "301": "FAST School of Computing",
    "302": "FAST School of Engineering",
    "303": "FAST School of Management",
    "313": "FAST School of Science & Humanities",
}

# Headers for requests
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

def get_highest_education(emp_id):
    """Fetches the highest education details from the faculty profile page."""
    profile_url = faculty_profile_url.format(emp_id)
    response1 = requests.post(profile_url, headers=headers)
    
    if response1.status_code == 200:
        profile = response1.json()
        
        if "listEEdu" in profile and profile["listEEdu"]:
            last_edu = profile["listEEdu"][0]
            
            degree = last_edu.get("Degree_Name", "N/A")
            subject = last_edu.get("Degree_Subject", "N/A")
            institute = last_edu.get("Degree_Institute", "N/A")
            year = last_edu.get("Degree_Year", "N/A")

            # Convert timestamp if available
            if isinstance(year, str) and year.startswith("/Date("):
                try:
                    timestamp = int(year[6:-2]) / 1000  # Extract timestamp
                    year = datetime.utcfromtimestamp(timestamp).strftime("%Y")
                except ValueError:
                    year = "N/A"
            
            return f"{degree} in {subject}, {institute} ({year})"
    
    return "N/A"

def extract_isb_faculty_data(dept_ids):
    """Fetches faculty data for the given department IDs and returns a list of dictionaries."""
    all_data = []
    
    for dept_id in dept_ids:
        url = faculty_api_url.format(dept_id)
        response = requests.get(url, headers=headers)
        
        if response.status_code == 200:
            try:
                faculty_list = response.json()
                for faculty in faculty_list:
                    emp_id = faculty.get("Emp_ID", "N/A")
                    name = f"{faculty.get('Title', '')} {faculty.get('Name', 'N/A')}".strip()
                    designation = faculty.get("Designation_Title", "N/A")
                    hec_approved = faculty.get("hec_supervisor", False)
                    email = faculty.get("Email", "N/A")
                    department_name = department_mapping.get(faculty.get("Dept_ID", "N/A"), "Unknown Department")
                    extension = faculty.get("Extension", "N/A")
                    image_url = f"http://isb.nu.edu.pk{faculty.get('ImagePath', '')}" if faculty.get("ImagePath") else "N/A"

                    # Fetch highest education
                    education = get_highest_education(emp_id)
                    if education:
                     education = re.sub(r'\s+', ' ', education).strip()
                    if email:
                     email = email.replace("\n", " ").strip()
                    if name:
                     name = name.replace("\n", " ").strip()
                    if designation:
                     designation = designation.replace("\n", " ").strip()
                    if department_name:
                     department_name = department_name.replace("\n", " ").strip()
                    if extension:
                     extension = extension.replace("\n", " ").strip()
                    # Append extracted data
                    all_data.append({
                        'ID': emp_id,
                        'Name': name,
                        'Designation': designation,
                        'HEC Approved PhD Supervisor': hec_approved,
                        'Highest Education': education,
                        'Email': email,
                        'Department': department_name,
                        'Extension': extension,
                        'ImageURL': image_url
                    })
            except ValueError:
                print(f"Failed to parse JSON for department ID {dept_id}")
        else:
            print(f"Request failed for department ID {dept_id} with status code {response.status_code}")
    
    return all_data

# %%
dept_ids = ["301", "302", "303","313"]
faculty_data = extract_isb_faculty_data(dept_ids)
df = pd.DataFrame(faculty_data)
save_csv(df,'isb.csv')
